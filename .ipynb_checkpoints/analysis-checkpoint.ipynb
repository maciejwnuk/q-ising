# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rc('axes', axisbelow=True)

# %%
# load complete graph data
q3n500 = np.loadtxt("full/500/3q_ising_complete.csv", delimiter = ',')
q4n500 = np.loadtxt("full/500/4q_ising_complete.csv", delimiter = ',')
q5n500 = np.loadtxt("full/500/5q_ising_complete.csv", delimiter = ',')
q6n500 = np.loadtxt("full/500/6q_ising_complete.csv", delimiter = ',')

q3n1000 = np.loadtxt("full/1000/3q_ising_complete.csv", delimiter = ',')
q4n1000 = np.loadtxt("full/1000/4q_ising_complete.csv", delimiter = ',')
q5n1000 = np.loadtxt("full/1000/5q_ising_complete.csv", delimiter = ',')
q6n1000 = np.loadtxt("full/1000/6q_ising_complete.csv", delimiter = ',')

# %%
plt.ylim(-0.02, 1.02)
plt.xlabel("T")
plt.ylabel("$m$")
plt.plot([], [], ' ', label="Warunki początkowe")
plt.scatter(q3n500[:, 0], q3n500[:, 1], label = "uporządkowane, n = 500")
plt.scatter(q3n500[:, 0], q3n500[:, 2], label = "nieuporządkowane, n = 500")
plt.scatter(q3n1000[:, 0], q3n1000[:, 1], label = "uporządkowane, n = 1000")
plt.scatter(q3n1000[:, 0], q3n1000[:, 2], label = "nieuporządkowane, n = 1000")
# plt.title("q = 3")
plt.legend()
plt.grid(color="lightgray")
plt.savefig("3q_ising_complete.png")

# %%
plt.ylim(-0.02, 1.02)
plt.xlabel("T")
plt.ylabel("m")
plt.plot([], [], ' ', label="Warunki początkowe")
plt.scatter(q4n500[:, 0], q4n500[:, 1], label = "uporządkowane, n = 500")
plt.scatter(q4n500[:, 0], q4n500[:, 2], label = "nieuporządkowane, n = 500")
plt.scatter(q4n1000[:, 0], q4n1000[:, 1], label = "uporządkowane, n = 1000")
plt.scatter(q4n1000[:, 0], q4n1000[:, 2], label = "nieuporządkowane, n = 1000")
# plt.title("q = 4")
plt.legend()
plt.grid(color="lightgray")
plt.savefig("4q_ising_complete.png")

# %%
plt.ylim(-0.02, 1.02)
plt.xlabel("T")
plt.ylabel("m")
plt.plot([], [], ' ', label="Warunki początkowe")
plt.scatter(q5n500[:, 0], q5n500[:, 1], label = "uporządkowane, n = 500")
plt.scatter(q5n500[:, 0], q5n500[:, 2], label = "nieuporządkowane, n = 500")
plt.scatter(q5n1000[:, 0], q5n1000[:, 1], label = "uporządkowane, n = 1000")
plt.scatter(q5n1000[:, 0], q5n1000[:, 2], label = "nieuporządkowane, n = 1000")
# plt.title("q = 5")
plt.legend()
plt.grid(color="lightgray")
plt.savefig("5q_ising_complete.png")

# %%
plt.ylim(-0.02, 1.02)
plt.xlabel("T")
plt.ylabel("m")
plt.plot([], [], ' ', label="Warunki początkowe")
plt.scatter(q6n500[:, 0], q6n500[:, 1], label = "uporządkowane, n = 500")
plt.scatter(q6n500[:, 0], q6n500[:, 2], label = "nieuporządkowane, n = 500")
plt.scatter(q6n1000[:, 0], q6n1000[:, 1], label = "uporządkowane, n = 1000")
plt.scatter(q6n1000[:, 0], q6n1000[:, 2], label = "nieuporządkowane, n = 1000")
# plt.title("q = 6")
plt.legend(bbox_to_anchor=(0.5,0.4), fontsize=9.5)

# plt.xlim(3.2, 4.5)
plt.grid(color="lightgray")
plt.savefig("6q_ising_complete.png")

# %%
# load rrg data
q3k10 = (abs(np.loadtxt("rrg/1/3q_ising_rrg_k10.csv", delimiter = ',')) +
         abs(np.loadtxt("rrg/2/3q_ising_rrg_k10.csv", delimiter = ',')) + 
         abs(np.loadtxt("rrg/3/3q_ising_rrg_k10.csv", delimiter = ',')) + 
         abs(np.loadtxt("rrg/4/3q_ising_rrg_k10.csv", delimiter = ',')) + 
         abs(np.loadtxt("rrg/5/3q_ising_rrg_k10.csv", delimiter = ','))) / 5

q3k50 = (abs(np.loadtxt("rrg/1/3q_ising_rrg_k50.csv", delimiter = ',')) +
         abs(np.loadtxt("rrg/2/3q_ising_rrg_k50.csv", delimiter = ',')) + 
         abs(np.loadtxt("rrg/3/3q_ising_rrg_k50.csv", delimiter = ',')) + 
         abs(np.loadtxt("rrg/4/3q_ising_rrg_k50.csv", delimiter = ',')) + 
         abs(np.loadtxt("rrg/5/3q_ising_rrg_k50.csv", delimiter = ','))) / 5

q4k10 = (abs(np.loadtxt("rrg/1/4q_ising_rrg_k10.csv", delimiter = ',')) +
         abs(np.loadtxt("rrg/2/4q_ising_rrg_k10.csv", delimiter = ',')) + 
         abs(np.loadtxt("rrg/3/4q_ising_rrg_k10.csv", delimiter = ',')) + 
         abs(np.loadtxt("rrg/4/4q_ising_rrg_k10.csv", delimiter = ',')) + 
         abs(np.loadtxt("rrg/5/4q_ising_rrg_k10.csv", delimiter = ','))) / 5 

q4k50 = (abs(np.loadtxt("rrg/1/4q_ising_rrg_k50.csv", delimiter = ',')) +
         abs(np.loadtxt("rrg/2/4q_ising_rrg_k50.csv", delimiter = ',')) + 
         abs(np.loadtxt("rrg/3/4q_ising_rrg_k50.csv", delimiter = ',')) + 
         abs(np.loadtxt("rrg/4/4q_ising_rrg_k50.csv", delimiter = ',')) + 
         abs(np.loadtxt("rrg/5/4q_ising_rrg_k50.csv", delimiter = ','))) / 5

q5k10 = (abs(np.loadtxt("rrg/1/5q_ising_rrg_k10.csv", delimiter = ',')) +
         abs(np.loadtxt("rrg/2/5q_ising_rrg_k10.csv", delimiter = ',')) + 
         abs(np.loadtxt("rrg/3/5q_ising_rrg_k10.csv", delimiter = ',')) + 
         abs(np.loadtxt("rrg/4/5q_ising_rrg_k10.csv", delimiter = ',')) + 
         abs(np.loadtxt("rrg/5/5q_ising_rrg_k10.csv", delimiter = ','))) / 5

q5k50 = (abs(np.loadtxt("rrg/1/5q_ising_rrg_k50.csv", delimiter = ',')) +
         abs(np.loadtxt("rrg/2/5q_ising_rrg_k50.csv", delimiter = ',')) + 
         abs(np.loadtxt("rrg/3/5q_ising_rrg_k50.csv", delimiter = ',')) + 
         abs(np.loadtxt("rrg/4/5q_ising_rrg_k50.csv", delimiter = ',')) + 
         abs(np.loadtxt("rrg/5/5q_ising_rrg_k50.csv", delimiter = ','))) / 5

q6k10 = (abs(np.loadtxt("rrg/1/6q_ising_rrg_k10.csv", delimiter = ',')) +
         abs(np.loadtxt("rrg/2/6q_ising_rrg_k10.csv", delimiter = ',')) + 
         abs(np.loadtxt("rrg/3/6q_ising_rrg_k10.csv", delimiter = ',')) + 
         abs(np.loadtxt("rrg/4/6q_ising_rrg_k10.csv", delimiter = ',')) + 
         abs(np.loadtxt("rrg/5/6q_ising_rrg_k10.csv", delimiter = ','))) / 5 

q6k50 = (abs(np.loadtxt("rrg/1/6q_ising_rrg_k50.csv", delimiter = ',')) +
         abs(np.loadtxt("rrg/2/6q_ising_rrg_k50.csv", delimiter = ',')) + 
         abs(np.loadtxt("rrg/3/6q_ising_rrg_k50.csv", delimiter = ',')) + 
         abs(np.loadtxt("rrg/4/6q_ising_rrg_k50.csv", delimiter = ',')) + 
         abs(np.loadtxt("rrg/5/6q_ising_rrg_k50.csv", delimiter = ','))) / 5

# %%
plt.ylim(-0.02, 1.02)
plt.xlabel("T")
plt.ylabel("m")
plt.plot([], [], ' ', label="Warunki początkowe")
plt.scatter(q3k10[:, 0], q3k10[:, 1], label = "uporządkowane, k = 10")
plt.scatter(q3k10[:, 0], q3k10[:, 2], label = "nieuporządkowane, k = 10")
plt.scatter(q3k50[:, 0], q3k50[:, 1], label = "uporządkowane, k = 50")
plt.scatter(q3k50[:, 0], q3k50[:, 2], label = "nieuporządkowane, k = 50")
# plt.title("q = 3")
plt.legend()
plt.grid(color="lightgray")
plt.savefig("3q_ising_rrg.png")

# %%
plt.ylim(-0.02, 1.02)
plt.xlabel("T")
plt.ylabel("m")
plt.plot([], [], ' ', label="Warunki początkowe")
plt.scatter(q4k10[10:, 0], q4k10[10:, 1], label = "uporządkowane, k = 10")
plt.scatter(q4k10[10:, 0], q4k10[10:, 2], label = "nieuporządkowane, k = 10")
plt.scatter(q4k50[10:, 0], q4k50[10:, 1], label = "uporządkowane, k = 50")
plt.scatter(q4k50[10:, 0], q4k50[10:, 2], label = "nieuporządkowane, k = 50")
# plt.title("q = 4")
plt.legend()
plt.grid(color="lightgray")
plt.savefig("4q_ising_rrg.png")

# %%
plt.ylim(-0.02, 1.02)
plt.xlabel("T")
plt.ylabel("m")
plt.plot([], [], ' ', label="Warunki początkowe")
plt.scatter(q5k10[:, 0], q5k10[:, 1], label = "uporządkowane, k = 10")
plt.scatter(q5k10[:, 0], q5k10[:, 2], label = "nieuporządkowane, k = 10")
plt.scatter(q5k50[:, 0], q5k50[:, 1], label = "uporządkowane, k = 50")
plt.scatter(q5k50[:, 0], q5k50[:, 2], label = "nieuporządkowane, k = 50")
# plt.title("q = 5")
plt.legend()
plt.grid(color="lightgray")
plt.savefig("5q_ising_rrg.png")

# %%
plt.ylim(-0.02, 1.02)
plt.xlabel("T")
plt.ylabel("m")
plt.plot([], [], ' ', label="Warunki początkowe")
plt.scatter(q6k10[:, 0], q6k10[:, 1], label = "uporządkowane, k = 10")
plt.scatter(q6k10[:, 0], q6k10[:, 2], label = "nieuporządkowane, k = 10")
plt.scatter(q6k50[:, 0], q6k50[:, 1], label = "uporządkowane, k = 50")
plt.scatter(q6k50[:, 0], q6k50[:, 2], label = "nieuporządkowane, k = 50")
# plt.title("q = 6")
plt.legend()
plt.grid(color="lightgray")
plt.savefig("6q_ising_rrg.png")
