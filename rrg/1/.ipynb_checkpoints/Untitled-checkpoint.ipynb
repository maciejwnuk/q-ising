# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("3q_ising_rrg_k10.csv", delimiter = ',')

# %%
plt.scatter(data[:, 0], abs(data[:, 1]))
plt.scatter(data[:, 0], abs(data[:, 2]))
